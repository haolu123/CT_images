# %% [markdown]
# ## Use ranking loss (spearman and weighted spearman loss) for CT image age prediction
# start at 10/23/2023 by Hao Lu for the first version
#
# by Hao:
#     I don't know it will work or not. Let's just try. I'm a little nervous.

# %% [markdown]
# ## Import models

# %%
import os
import glob
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
    Flipd,
    RandAffined,
    ToTensord,
    RepeatChanneld,
)
from monai.data import CacheDataset, DataLoader, Dataset, DistributedSampler, SmartCacheDataset, load_decathlon_datalist
# import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import json
import torch
import torch.nn as nn
from monai.networks.nets import UNet,SEResNet50
import torchsort
from tqdm import tqdm
from torch.optim.lr_scheduler import CosineAnnealingLR

# %% [markdown]
# ## Load data
# data director: /isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/original/
# label director: /isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/labels.json

# %%
# set data directory


data_dir = "/isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/original/"
label_dir = "/isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/"
label_file = "labels.json"
with open(os.path.join(label_dir, label_file), 'r') as f:
    labels = json.load(f)

# get the image file names and labels
image_name_list = [os.path.join(data_dir, str(image_name['id'])+'.nii') for image_name in labels]


label_list = [label['age'] for label in labels]
max_age = max(label_list)
min_age = min(label_list)
label_list = [[(label-min_age)/(max_age-min_age)] for label in label_list] # Not sure it is still a good idea to normalize the label for spearman loss

data_dicts = []
for image_name, label in zip(image_name_list, label_list):
    if os.path.exists(image_name):
        data_dicts.append({"image": image_name, "label": label})
train_files, val_files = data_dicts[:-200], data_dicts[-200:]

# %%
# define hyperparameters
batch_size = 20
num_workers = 10
train_sampler = None
lr = 1

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-500,
            a_max=1500, 
            b_min=0.0, 
            b_max=1.0, 
            clip=True,
        ),
        # RepeatChanneld(keys=["image"],repeats=3),
        ToTensord(keys=["image", "label"]),
        # RandCropByPosNegLabeld(
        #     keys=["image", "label"],
        #     label_key="label",
        #     spatial_size=(96, 96),
        #     pos=1,
        #     neg=1,
        #     num_samples=4,
        #     image_key="image",
        #     image_threshold=0,
        # ),
        # user can also add other random transforms
        # RandAffined(
        #     keys=['image', 'label'],
        #     mode=('bilinear', 'nearest'),
        #     prob=1.0, spatial_size=(96, 96),
        #     rotate_range=(0, 0, np.pi/15),
        #     scale_range=(0.1, 0.1, 0.1)),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-500,
            a_max=1500,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        # # RepeatChanneld(keys=["image"],repeats=3),
        ToTensord(keys=["image", "label"]),
    ]
)

train_ds = Dataset(data=train_files, transform=train_transforms)
val_ds = Dataset(data=val_files, transform=val_transforms)

train_loader = DataLoader(train_ds, batch_size=batch_size, num_workers=num_workers, sampler=train_sampler,shuffle=True, drop_last=True)
val_loader = DataLoader(val_ds, batch_size=batch_size, num_workers=num_workers, shuffle=False, drop_last=True)

# %% [markdown]
# ## check the dataloader

# %%
from monai.utils import set_determinism, first
import matplotlib.pyplot as plt

check_ds = Dataset(data=train_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
iamge = check_data["image"][0][0]
label = check_data["label"][0]


# plot the slice [:, :, 50]
plt.figure("check", (12, 6))
plt.subplot(1, 2, 1)
plt.title("moving_image")
plt.imshow(iamge[:, :], cmap="gray")



plt.show()
plt.show()

# %%
check_data["label"].shape
# Out:
# torch.Size([1, 1])

# %% [markdown]
# ## Spearman loss

# %%
class WeightedSpearmanLoss(nn.Module):
    """
        Spearman Loss
    """

    def __init__(self, *args, **kwargs) -> None:
        super().__init__(*args, **kwargs)
    
    def forward(self, pred: torch.tensor, target: torch.tensor, target_sort: torch.tensor, k=2, s=5, **kw) -> torch.tensor:
        
        pred_rank = torchsort.soft_rank(pred, **kw)
        target_rank = torchsort.soft_rank(target, **kw)
        
        target_sort = target_sort.flatten()
        W = torch.sqrt( (target_sort[pred_rank.flatten().long()-1] - target_sort[target_rank.flatten().long()-1]) ** 2 ).requires_grad_(False)
        # w = torch.tensor([0,0,0,0,19])
        pred_rank = pred_rank - pred_rank.mean()
        pred_rank = pred_rank / pred_rank.norm()
        target_rank = target_rank - target_rank.mean()
        target_rank = target_rank / target_rank.norm()
        
        W = 1/(1 + torch.exp(-k*(W-s)))
        W = W / W.sum()*len(W)
        return -(pred_rank * target_rank * W).sum()
    
class SpearmanLoss(nn.Module):
    """
        Spearman Loss
    """

    def __init__(self, *args, **kwargs) -> None:
        super().__init__(*args, **kwargs)
    
    def forward(self, pred: torch.tensor, target: torch.tensor, **kw) -> torch.tensor:
        """
            pred: (B, 1)
            target: (B, 1)
        """
        pred = torchsort.soft_rank(pred, **kw)
        target = torchsort.soft_rank(target, **kw)
        pred = pred - pred.mean()
        pred = pred / pred.norm()
        target = target - target.mean()
        target = target / target.norm()
        return -(pred * target).sum()

# %%
device = torch.device("cuda:0")
model = SEResNet50(spatial_dims=2, in_channels=1, pretrained=False, num_classes=1)
model.to(device)
huber_loss = nn.SmoothL1Loss()
spearman_loss = SpearmanLoss()
weighted_spearman_loss = WeightedSpearmanLoss()
optimizer = torch.optim.Adam(model.parameters(), lr)

# Number of epochs
loop_epochs = 100
num_loop = 2

# Cosine learning rate scheduler
scheduler = CosineAnnealingLR(optimizer, T_max=loop_epochs, eta_min=0.001)

# %%
def spearman_hard(traget1, pred):
    pred = get_rank(pred, [i for i in range(pred.shape[1])]).float()
    traget1 = get_rank(traget1, [i for i in range(traget1.shape[1])]).float()
    pred = pred - pred.mean()
    pred = pred / pred.norm()
    traget1 = traget1 - traget1.mean()
    traget1 = traget1 / traget1.norm()
    return (pred * traget1).sum()

def weighted_spearmanr(pred, target, target_sort, k=2, s=5, **kw):
    pred_rank = torchsort.soft_rank(pred, **kw)
    target_rank = torchsort.soft_rank(target, **kw)
    
    target_sort = target_sort.flatten()
    W = torch.sqrt( (target_sort[pred_rank.flatten().long()-1] - target_sort[target_rank.flatten().long()-1]) ** 2 ).requires_grad_(False)
    # w = torch.tensor([0,0,0,0,19])
    pred_rank = pred_rank - pred_rank.mean()
    pred_rank = pred_rank / pred_rank.norm()
    target_rank = target_rank - target_rank.mean()
    target_rank = target_rank / target_rank.norm()
    
    W = 1/(1 + torch.exp(-k*(W-s)))

    return (pred_rank * target_rank * W).sum(), W

def spearmanr(pred, target, **kw):
    pred = torchsort.soft_rank(pred, **kw)
    target = torchsort.soft_rank(target, **kw)
    pred = pred - pred.mean()
    pred = pred / pred.norm()
    target = target - target.mean()
    target = target / target.norm()
    return (pred * target).sum()

def get_rank(x, indices):
   vals = x[list(range(len(x))), indices]
   return (x < vals[:, None]).long().sum(1)

def spearman_hard_eval(traget1, pred):
    pred = get_rank_eval(pred).float()
    traget1 = get_rank_eval(traget1).float()
    pred = pred - pred.mean()
    pred = pred / pred.norm()
    traget1 = traget1 - traget1.mean()
    traget1 = traget1 / traget1.norm()
    return (pred * traget1).sum()

def get_rank_eval(x):
   vals = x[0, :]
   return (x < vals[:, None]).long().sum(1)

# %%
x = torch.tensor([[1,2,3,4,5,5,4,3,2,1]])
get_rank_eval(x)
# Out:
# tensor([0, 2, 4, 6, 8, 8, 6, 4, 2, 0])

# %%
val_interval = 5

for lr in [0.0001, 0.001, 0.01, 0.1, 1]:

    metric_val = []
    loss_val = []
    best_metric = -1
    for epoch in range(loop_epochs * num_loop):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{loop_epochs * num_loop}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            step += 1
            inputs, labels = (
                batch_data["image"].to(device),
                batch_data["label"].to(device),
            )
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = spearman_loss(outputs.t(), labels.t())
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            # print(f"{step}/{len(train_ds) // train_loader.batch_size}, train_loss: {loss.item():.4f}")
        epoch_loss /= step
        # Step the scheduler
        scheduler.step()
        # print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

        if (epoch+1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                val_spearman_metric = 0
                val_step = 0
                for val_data in val_loader:
                    val_images, val_labels = (
                        val_data["image"].to(device),
                        val_data["label"].to(device),
                    )
                    val_outputs = model(val_images)
                    val_loss = spearman_hard_eval(val_outputs.t(), val_labels.t())
                    val_spearman_metric += val_loss
                    val_step += 1
                val_spearman_metric /= val_step
                if val_spearman_metric > best_metric:
                    best_metric = val_spearman_metric
                    torch.save(model.state_dict(), "best_metric_model_lr_{}_batchsize_{}.pth".format(lr, batch_size))
                print(f"current epoch: {epoch + 1} current spearman: {val_spearman_metric:.4f} best spearman: {best_metric:.4f}")
                metric_val.append(val_spearman_metric.cpu())
                loss_val.append(epoch_loss)

    # Plot the loss curve
    plt.figure("train", (12, 6))
    plt.subplot(1, 2, 1)
    plt.title("Epoch Average Loss")
    x = [i*val_interval for i in range(len(loss_val))]
    plt.xlabel("epoch")
    plt.plot(x, loss_val, color="red")
    plt.subplot(1, 2, 2)
    plt.title("Epoch Average Spearman")
    x = [i*val_interval for i in range(len(metric_val))]
    plt.xlabel("epoch")
    plt.plot(x, metric_val, color="red")
    plt.savefig("loss_lr_{}_batchsize_{}.png".format(lr, batch_size))
    plt.close("train")

    # save the loss and metric
    with open("loss_lr_{}_batchsize_{}.txt".format(lr, batch_size), "w") as f:
        for i in loss_val:
            f.write(str(i))
            f.write("\n")
    with open("metric_lr_{}_batchsize_{}.txt".format(lr, batch_size), "w") as f:
        for i in metric_val:
            f.write(str(i))
            f.write("\n")
# Out:
# ----------
# epoch 1/200
# ----------
# epoch 2/200
# ----------
# epoch 3/200
# ----------
# epoch 4/200
# ----------
# epoch 5/200
# current epoch: 5 current spearman: 0.0298 best spearman: 0.0298
# ----------
# epoch 6/200
# ----------
# epoch 7/200
# ----------
# epoch 8/200
# ----------
# epoch 9/200
# ----------
# epoch 10/200
# current epoch: 10 current spearman: 0.0121 best spearman: 0.0298
# ----------
# epoch 11/200
# ----------
# epoch 12/200
# ----------
# epoch 13/200
# ----------
# epoch 14/200
# ----------
# epoch 15/200
# current epoch: 15 current spearman: -0.0077 best spearman: 0.0298
# ----------
# epoch 16/200
# ----------
# epoch 17/200
# ----------
# epoch 18/200
# ----------
# epoch 19/200
# ----------
# epoch 20/200
# current epoch: 20 current spearman: -0.0168 best spearman: 0.0298
# ----------
# epoch 21/200
# ----------
# epoch 22/200
# ----------
# epoch 23/200
# ----------
# epoch 24/200
# ----------
# epoch 25/200
# current epoch: 25 current spearman: -0.0091 best spearman: 0.0298
# ----------
# epoch 26/200
# ----------
# epoch 27/200
# ----------
# epoch 28/200
# ----------
# epoch 29/200
# ----------
# epoch 30/200
# current epoch: 30 current spearman: 0.0038 best spearman: 0.0298
# ----------
# epoch 31/200
# ----------
# epoch 32/200
# ----------
# epoch 33/200
# ----------
# epoch 34/200
# ----------
# epoch 35/200
# current epoch: 35 current spearman: 0.0148 best spearman: 0.0298
# ----------
# epoch 36/200
# ----------
# epoch 37/200
# ----------
# epoch 38/200
# ----------
# epoch 39/200
# ----------
# epoch 40/200
# current epoch: 40 current spearman: 0.0059 best spearman: 0.0298
# ----------
# epoch 41/200
# ----------
# epoch 42/200
# ----------
# epoch 43/200
# ----------
# epoch 44/200
# ----------
# epoch 45/200
# current epoch: 45 current spearman: 0.0094 best spearman: 0.0298
# ----------
# epoch 46/200
# ----------
# epoch 47/200
# ----------
# epoch 48/200
# ----------
# epoch 49/200
# ----------
# epoch 50/200
# current epoch: 50 current spearman: -0.0213 best spearman: 0.0298
# ----------
# epoch 51/200
# ----------
# epoch 52/200
# ----------
# epoch 53/200
# ----------
# epoch 54/200
# ----------
# epoch 55/200
# current epoch: 55 current spearman: -0.0494 best spearman: 0.0298
# ----------
# epoch 56/200
# ----------
# epoch 57/200
# ----------
# epoch 58/200
# ----------
# epoch 59/200
# ----------
# epoch 60/200
# current epoch: 60 current spearman: -0.0361 best spearman: 0.0298
# ----------
# epoch 61/200
# ----------
# epoch 62/200
# ----------
# epoch 63/200
# ----------
# epoch 64/200
# ----------
# epoch 65/200
# current epoch: 65 current spearman: -0.0451 best spearman: 0.0298
# ----------
# epoch 66/200
# ----------
# epoch 67/200
# ----------
# epoch 68/200
# ----------
# epoch 69/200
# ----------
# epoch 70/200
# current epoch: 70 current spearman: -0.0410 best spearman: 0.0298
# ----------
# epoch 71/200
# ----------
# epoch 72/200
# ----------
# epoch 73/200
# ----------
# epoch 74/200
# ----------
# epoch 75/200
# current epoch: 75 current spearman: 0.0205 best spearman: 0.0298
# ----------
# epoch 76/200
# ----------
# epoch 77/200
# ----------
# epoch 78/200
# ----------
# epoch 79/200
# ----------
# epoch 80/200
# current epoch: 80 current spearman: 0.0073 best spearman: 0.0298
# ----------
# epoch 81/200
# ----------
# epoch 82/200
# ----------
# epoch 83/200
# ----------
# epoch 84/200
# ----------
# epoch 85/200
# current epoch: 85 current spearman: 0.0116 best spearman: 0.0298
# ----------
# epoch 86/200
# ----------
# epoch 87/200
# ----------
# epoch 88/200
# ----------
# epoch 89/200
# ----------
# epoch 90/200
# current epoch: 90 current spearman: -0.0344 best spearman: 0.0298
# ----------
# epoch 91/200
# ----------
# epoch 92/200
# ----------
# epoch 93/200
# ----------
# epoch 94/200
# ----------
# epoch 95/200
# current epoch: 95 current spearman: -0.0270 best spearman: 0.0298
# ----------
# epoch 96/200
# ----------
# epoch 97/200
# ----------
# epoch 98/200
# ----------
# epoch 99/200
# ----------
# epoch 100/200
# current epoch: 100 current spearman: -0.0336 best spearman: 0.0298
# ----------
# epoch 101/200
# ----------
# epoch 102/200
# ----------
# epoch 103/200
# ----------
# epoch 104/200
# ----------
# epoch 105/200
# current epoch: 105 current spearman: -0.0369 best spearman: 0.0298
# ----------
# epoch 106/200
# ----------
# epoch 107/200
# ----------
# epoch 108/200
# ----------
# epoch 109/200
# ----------
# epoch 110/200
# current epoch: 110 current spearman: -0.0359 best spearman: 0.0298
# ----------
# epoch 111/200
# ----------
# epoch 112/200
# ----------
# epoch 113/200
# ----------
# epoch 114/200
# ----------
# epoch 115/200
# current epoch: 115 current spearman: -0.0095 best spearman: 0.0298
# ----------
# epoch 116/200
# ----------
# epoch 117/200
# ----------
# epoch 118/200
# ----------
# epoch 119/200
# ----------
# epoch 120/200
# current epoch: 120 current spearman: -0.0204 best spearman: 0.0298
# ----------
# epoch 121/200
# ----------
# epoch 122/200
# ----------
# epoch 123/200
# ----------
# epoch 124/200
# ----------
# epoch 125/200
# current epoch: 125 current spearman: -0.0060 best spearman: 0.0298
# ----------
# epoch 126/200
# ----------
# epoch 127/200
# ----------
# epoch 128/200
# ----------
# epoch 129/200
# ----------
# epoch 130/200
# current epoch: 130 current spearman: -0.0024 best spearman: 0.0298
# ----------
# epoch 131/200
# ----------
# epoch 132/200
# ----------
# epoch 133/200
# ----------
# epoch 134/200
# ----------
# epoch 135/200
# current epoch: 135 current spearman: -0.0170 best spearman: 0.0298
# ----------
# epoch 136/200
# ----------
# epoch 137/200
# ----------
# epoch 138/200
# ----------
# epoch 139/200
# ----------
# epoch 140/200
# current epoch: 140 current spearman: -0.0137 best spearman: 0.0298
# ----------
# epoch 141/200
# ----------
# epoch 142/200
# ----------
# epoch 143/200
# ----------
# epoch 144/200
# ----------
# epoch 145/200
# current epoch: 145 current spearman: -0.0103 best spearman: 0.0298
# ----------
# epoch 146/200
# ----------
# epoch 147/200
# ----------
# epoch 148/200
# ----------
# epoch 149/200
# ----------
# epoch 150/200
# current epoch: 150 current spearman: -0.0003 best spearman: 0.0298
# ----------
# epoch 151/200
# ----------
# epoch 152/200
# ----------
# epoch 153/200
# ----------
# epoch 154/200
# ----------
# epoch 155/200
# current epoch: 155 current spearman: -0.1295 best spearman: 0.0298
# ----------
# epoch 156/200
# ----------
# epoch 157/200
# ----------
# epoch 158/200
# ----------
# epoch 159/200
# ----------
# epoch 160/200
# current epoch: 160 current spearman: 0.0065 best spearman: 0.0298
# ----------
# epoch 161/200
# ----------
# epoch 162/200
# ----------
# epoch 163/200
# ----------
# epoch 164/200
# ----------
# epoch 165/200
# current epoch: 165 current spearman: -0.0098 best spearman: 0.0298
# ----------
# epoch 166/200
# ----------
# epoch 167/200
# ----------
# epoch 168/200
# ----------
# epoch 169/200
# ----------
# epoch 170/200
# current epoch: 170 current spearman: -0.0379 best spearman: 0.0298
# ----------
# epoch 171/200
# ----------
# epoch 172/200
# ----------
# epoch 173/200
# ----------
# epoch 174/200
# ----------
# epoch 175/200
# current epoch: 175 current spearman: -0.0266 best spearman: 0.0298
# ----------
# epoch 176/200
# ----------
# epoch 177/200
# ----------
# epoch 178/200
# ----------
# epoch 179/200
# ----------
# epoch 180/200
# current epoch: 180 current spearman: -0.0360 best spearman: 0.0298
# ----------
# epoch 181/200
# ----------
# epoch 182/200
# ----------
# epoch 183/200
# ----------
# epoch 184/200
# ----------
# epoch 185/200
# current epoch: 185 current spearman: -0.0324 best spearman: 0.0298
# ----------
# epoch 186/200
# ----------
# epoch 187/200
# ----------
# epoch 188/200
# ----------
# epoch 189/200
# ----------
# epoch 190/200
# current epoch: 190 current spearman: -0.0314 best spearman: 0.0298
# ----------
# epoch 191/200
# ----------
# epoch 192/200
# ----------
# epoch 193/200
# ----------
# epoch 194/200
# ----------
# epoch 195/200
# current epoch: 195 current spearman: -0.0331 best spearman: 0.0298
# ----------
# epoch 196/200
# ----------
# epoch 197/200
# ----------
# epoch 198/200
# ----------
# epoch 199/200
# ----------
# epoch 200/200
# current epoch: 200 current spearman: -0.0356 best spearman: 0.0298
# ----------
# epoch 1/200
# ----------
# epoch 2/200
# ----------
# epoch 3/200
# ----------
# epoch 4/200
# ----------
# epoch 5/200
# current epoch: 5 current spearman: -0.0280 best spearman: -0.0280
# ----------
# epoch 6/200
# ----------
# epoch 7/200
# ----------
# epoch 8/200
# ----------
# epoch 9/200
# ----------
# epoch 10/200
# current epoch: 10 current spearman: -0.0375 best spearman: -0.0280
# ----------
# epoch 11/200
# ----------
# epoch 12/200
# ----------
# epoch 13/200
# ----------
# epoch 14/200
# ----------
# epoch 15/200
# current epoch: 15 current spearman: -0.0494 best spearman: -0.0280
# ----------
# epoch 16/200
# ----------
# epoch 17/200
# ----------
# epoch 18/200
# ----------
# epoch 19/200
# ----------
# epoch 20/200
# current epoch: 20 current spearman: -0.0869 best spearman: -0.0280
# ----------
# epoch 21/200
# ----------
# epoch 22/200
# ----------
# epoch 23/200
# ----------
# epoch 24/200
# ----------
# epoch 25/200
# current epoch: 25 current spearman: -0.1084 best spearman: -0.0280
# ----------
# epoch 26/200
# ----------
# epoch 27/200
# ----------
# epoch 28/200
# ----------
# epoch 29/200
# ----------
# epoch 30/200
# current epoch: 30 current spearman: -0.0931 best spearman: -0.0280
# ----------
# epoch 31/200
# ----------
# epoch 32/200
# ----------
# epoch 33/200
# ----------
# epoch 34/200
# ----------
# epoch 35/200
# current epoch: 35 current spearman: -0.0879 best spearman: -0.0280
# ----------
# epoch 36/200
# ----------
# epoch 37/200
# ----------
# epoch 38/200
# ----------
# epoch 39/200
# ----------
# epoch 40/200
# current epoch: 40 current spearman: -0.0953 best spearman: -0.0280
# ----------
# epoch 41/200
# ----------
# epoch 42/200
# ----------
# epoch 43/200
# ----------
# epoch 44/200
# ----------
# epoch 45/200
# current epoch: 45 current spearman: -0.0893 best spearman: -0.0280
# ----------
# epoch 46/200
# ----------
# epoch 47/200
# ----------
# epoch 48/200
# ----------
# epoch 49/200
# ----------
# epoch 50/200
# current epoch: 50 current spearman: -0.0928 best spearman: -0.0280
# ----------
# epoch 51/200
# ----------
# epoch 52/200
# ----------
# epoch 53/200
# ----------
# epoch 54/200
# ----------
# epoch 55/200
# current epoch: 55 current spearman: -0.0687 best spearman: -0.0280
# ----------
# epoch 56/200
# ----------
# epoch 57/200
# ----------
# epoch 58/200
# ----------
# epoch 59/200
# ----------
# epoch 60/200
# current epoch: 60 current spearman: -0.0677 best spearman: -0.0280
# ----------
# epoch 61/200
# ----------
# epoch 62/200
# ----------
# epoch 63/200
# ----------
# epoch 64/200
# ----------
# epoch 65/200
# current epoch: 65 current spearman: -0.0655 best spearman: -0.0280
# ----------
# epoch 66/200
# ----------
# epoch 67/200
# ----------
# epoch 68/200
# ----------
# epoch 69/200
# ----------
# epoch 70/200
# current epoch: 70 current spearman: -0.0694 best spearman: -0.0280
# ----------
# epoch 71/200
# ----------
# epoch 72/200
# ----------
# epoch 73/200
# ----------
# epoch 74/200
# ----------
# epoch 75/200
# current epoch: 75 current spearman: -0.0654 best spearman: -0.0280
# ----------
# epoch 76/200
# ----------
# epoch 77/200
# ----------
# epoch 78/200
# ----------
# epoch 79/200
# ----------
# epoch 80/200
# current epoch: 80 current spearman: -0.0711 best spearman: -0.0280
# ----------
# epoch 81/200
# ----------
# epoch 82/200
# ----------
# epoch 83/200
# ----------
# epoch 84/200
# ----------
# epoch 85/200
# current epoch: 85 current spearman: -0.0579 best spearman: -0.0280
# ----------
# epoch 86/200
# ----------
# epoch 87/200
# ----------
# epoch 88/200
# ----------
# epoch 89/200
# ----------
# epoch 90/200
# current epoch: 90 current spearman: -0.0506 best spearman: -0.0280
# ----------
# epoch 91/200
# ----------
# epoch 92/200
# ----------
# epoch 93/200
# ----------
# epoch 94/200
# ----------
# epoch 95/200
# current epoch: 95 current spearman: -0.0683 best spearman: -0.0280
# ----------
# epoch 96/200
# ----------
# epoch 97/200
# ----------
# epoch 98/200
# ----------
# epoch 99/200
# ----------
# epoch 100/200
# current epoch: 100 current spearman: -0.0682 best spearman: -0.0280
# ----------
# epoch 101/200
# ----------
# epoch 102/200
# ----------
# epoch 103/200
# ----------
# epoch 104/200
# ----------
# epoch 105/200
# current epoch: 105 current spearman: -0.0493 best spearman: -0.0280
# ----------
# epoch 106/200
# ----------
# epoch 107/200
# ----------
# epoch 108/200
# ----------
# epoch 109/200
# ----------
# epoch 110/200
# current epoch: 110 current spearman: -0.0688 best spearman: -0.0280
# ----------
# epoch 111/200
# ----------
# epoch 112/200
# ----------
# epoch 113/200
# ----------
# epoch 114/200
# ----------
# epoch 115/200
# current epoch: 115 current spearman: -0.0671 best spearman: -0.0280
# ----------
# epoch 116/200
# ----------
# epoch 117/200
# ----------
# epoch 118/200
# ----------
# epoch 119/200
# ----------
# epoch 120/200
# current epoch: 120 current spearman: -0.0552 best spearman: -0.0280
# ----------
# epoch 121/200
# ----------
# epoch 122/200
# ----------
# epoch 123/200
# ----------
# epoch 124/200
# ----------
# epoch 125/200
# current epoch: 125 current spearman: -0.0564 best spearman: -0.0280
# ----------
# epoch 126/200
# ----------
# epoch 127/200
# ----------
# epoch 128/200
# ----------
# epoch 129/200
# ----------
# epoch 130/200
# current epoch: 130 current spearman: 0.0105 best spearman: 0.0105
# ----------
# epoch 131/200
# ----------
# epoch 132/200
# ----------
# epoch 133/200
# ----------
# epoch 134/200
# ----------
# epoch 135/200
# current epoch: 135 current spearman: 0.0170 best spearman: 0.0170
# ----------
# epoch 136/200
# ----------
# epoch 137/200
# ----------
# epoch 138/200
# ----------
# epoch 139/200
# ----------
# epoch 140/200
# current epoch: 140 current spearman: 0.0110 best spearman: 0.0170
# ----------
# epoch 141/200
# ----------
# epoch 142/200
# ----------
# epoch 143/200
# ----------
# epoch 144/200
# ----------
# epoch 145/200
# current epoch: 145 current spearman: 0.0147 best spearman: 0.0170
# ----------
# epoch 146/200
# ----------
# epoch 147/200
# ----------
# epoch 148/200
# ----------
# epoch 149/200
# ----------
# epoch 150/200
# current epoch: 150 current spearman: 0.0077 best spearman: 0.0170
# ----------
# epoch 151/200
# ----------
# epoch 152/200
# ----------
# epoch 153/200
# ----------
# epoch 154/200
# ----------
# epoch 155/200
# current epoch: 155 current spearman: 0.0158 best spearman: 0.0170
# ----------
# epoch 156/200
# ----------
# epoch 157/200
# ----------
# epoch 158/200
# ----------
# epoch 159/200
# ----------
# epoch 160/200
# current epoch: 160 current spearman: 0.0141 best spearman: 0.0170
# ----------
# epoch 161/200
# ----------
# epoch 162/200
# ----------
# epoch 163/200
# ----------
# epoch 164/200
# ----------
# epoch 165/200
# current epoch: 165 current spearman: 0.0196 best spearman: 0.0196
# ----------
# epoch 166/200
# ----------
# epoch 167/200
# ----------
# epoch 168/200
# ----------
# epoch 169/200
# ----------
# epoch 170/200
# current epoch: 170 current spearman: 0.0142 best spearman: 0.0196
# ----------
# epoch 171/200
# ----------
# epoch 172/200
# ----------
# epoch 173/200
# ----------
# epoch 174/200
# ----------
# epoch 175/200
# current epoch: 175 current spearman: 0.0073 best spearman: 0.0196
# ----------
# epoch 176/200
# ----------
# epoch 177/200
# ----------
# epoch 178/200
# ----------
# epoch 179/200
# ----------
# epoch 180/200
# current epoch: 180 current spearman: 0.0112 best spearman: 0.0196
# ----------
# epoch 181/200
# ----------
# epoch 182/200
# ----------
# epoch 183/200
# ----------
# epoch 184/200
# ----------
# epoch 185/200
# current epoch: 185 current spearman: 0.0143 best spearman: 0.0196
# ----------
# epoch 186/200
# ----------
# epoch 187/200
# ----------
# epoch 188/200
# ----------
# epoch 189/200
# ----------
# epoch 190/200
# current epoch: 190 current spearman: 0.0106 best spearman: 0.0196
# ----------
# epoch 191/200
# ----------
# epoch 192/200
# ----------
# epoch 193/200
# ----------
# epoch 194/200
# ----------
# epoch 195/200
# current epoch: 195 current spearman: 0.0250 best spearman: 0.0250
# ----------
# epoch 196/200
# ----------
# epoch 197/200
# ----------
# epoch 198/200
# ----------
# epoch 199/200
# ----------
# epoch 200/200
# current epoch: 200 current spearman: 0.0187 best spearman: 0.0250
# ----------
# epoch 1/200
# ----------
# epoch 2/200
# ----------
# epoch 3/200
# ----------
# epoch 4/200
# ----------
# epoch 5/200
# current epoch: 5 current spearman: 0.0191 best spearman: 0.0191
# ----------
# epoch 6/200
# ----------
# epoch 7/200
# ----------
# epoch 8/200
# ----------
# epoch 9/200
# ----------
# epoch 10/200
# current epoch: 10 current spearman: 0.0262 best spearman: 0.0262
# ----------
# epoch 11/200
# ----------
# epoch 12/200
# ----------
# epoch 13/200
# ----------
# epoch 14/200
# ----------
# epoch 15/200
# current epoch: 15 current spearman: 0.0169 best spearman: 0.0262
# ----------
# epoch 16/200
# ----------
# epoch 17/200
# ----------
# epoch 18/200
# ----------
# epoch 19/200
# ----------
# epoch 20/200
# current epoch: 20 current spearman: 0.0073 best spearman: 0.0262
# ----------
# epoch 21/200
# ----------
# epoch 22/200
# ----------
# epoch 23/200
# ----------
# epoch 24/200
# ----------
# epoch 25/200
# current epoch: 25 current spearman: 0.0160 best spearman: 0.0262
# ----------
# epoch 26/200
# ----------
# epoch 27/200
# ----------
# epoch 28/200
# ----------
# epoch 29/200
# ----------
# epoch 30/200
# current epoch: 30 current spearman: 0.0097 best spearman: 0.0262
# ----------
# epoch 31/200
# ----------
# epoch 32/200
# ----------
# epoch 33/200
# ----------
# epoch 34/200
# ----------
# epoch 35/200
# current epoch: 35 current spearman: 0.0202 best spearman: 0.0262
# ----------
# epoch 36/200
# ----------
# epoch 37/200
# ----------
# epoch 38/200
# ----------
# epoch 39/200
# ----------
# epoch 40/200
# current epoch: 40 current spearman: 0.0191 best spearman: 0.0262
# ----------
# epoch 41/200
# ----------
# epoch 42/200
# ----------
# epoch 43/200
# ----------
# epoch 44/200
# ----------
# epoch 45/200
# current epoch: 45 current spearman: 0.0163 best spearman: 0.0262
# ----------
# epoch 46/200
# ----------
# epoch 47/200
# ----------
# epoch 48/200
# ----------
# epoch 49/200
# ----------
# epoch 50/200
# current epoch: 50 current spearman: 0.0185 best spearman: 0.0262
# ----------
# epoch 51/200
# ----------
# epoch 52/200
# ----------
# epoch 53/200
# ----------
# epoch 54/200
# ----------
# epoch 55/200
# current epoch: 55 current spearman: 0.0157 best spearman: 0.0262
# ----------
# epoch 56/200
# ----------
# epoch 57/200
# ----------
# epoch 58/200
# ----------
# epoch 59/200
# ----------
# epoch 60/200
# current epoch: 60 current spearman: 0.0198 best spearman: 0.0262
# ----------
# epoch 61/200
# ----------
# epoch 62/200
# ----------
# epoch 63/200
# ----------
# epoch 64/200
# ----------
# epoch 65/200
# current epoch: 65 current spearman: 0.0457 best spearman: 0.0457
# ----------
# epoch 66/200
# ----------
# epoch 67/200
# ----------
# epoch 68/200
# ----------
# epoch 69/200
# ----------
# epoch 70/200
# current epoch: 70 current spearman: -0.0421 best spearman: 0.0457
# ----------
# epoch 71/200
# ----------
# epoch 72/200
# ----------
# epoch 73/200
# ----------
# epoch 74/200
# ----------
# epoch 75/200
# current epoch: 75 current spearman: -0.0382 best spearman: 0.0457
# ----------
# epoch 76/200
# ----------
# epoch 77/200
# ----------
# epoch 78/200
# ----------
# epoch 79/200
# ----------
# epoch 80/200
# current epoch: 80 current spearman: -0.0415 best spearman: 0.0457
# ----------
# epoch 81/200
# ----------
# epoch 82/200
# ----------
# epoch 83/200
# ----------
# epoch 84/200
# ----------
# epoch 85/200
# current epoch: 85 current spearman: -0.0386 best spearman: 0.0457
# ----------
# epoch 86/200
# ----------
# epoch 87/200
# ----------
# epoch 88/200
# ----------
# epoch 89/200
# ----------
# epoch 90/200

# %%
# Plot the loss curve
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i*val_interval for i in range(len(loss_val))]
plt.xlabel("epoch")
plt.plot(x, loss_val, color="red")
plt.subplot(1, 2, 2)
plt.title("Epoch Average Spearman")
x = [i*val_interval for i in range(len(metric_val))]
plt.xlabel("epoch")
plt.plot(x, [i.cpu() for i in metric_val], color="red")
plt.savefig("loss_lr_{}_batchsize_{}.png".format(lr, batch_size))

# %%
exit()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
