# %% [markdown]
# ## Use ranking loss (spearman and weighted spearman loss) for CT image age prediction
# start at 10/23/2023 by Hao Lu for the first version
#
# by Hao:
#     I don't know it will work or not. Let's just try. I'm a little nervous.

# %% [markdown]
# ## Import models

# %%
import os
import glob
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
    Flipd,
    RandAffined,
    ToTensord,
    RepeatChanneld,
)
from monai.data import CacheDataset, DataLoader, Dataset, DistributedSampler, SmartCacheDataset, load_decathlon_datalist
# import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import json
import torch
import torch.nn as nn
from monai.networks.nets import UNet,SEResNet50
import torchsort
from tqdm import tqdm
from torch.optim.lr_scheduler import CosineAnnealingLR
import re

from copy import deepcopy

# %% [markdown]
# ## Load data
# data director: /isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/original/
# label director: /isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/labels.json

# %%
# set data directory


data_dir = "/isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/original/"
label_dir = "/isilon/datalake/cialab/original/cialab/image_database/d00143/2022_dataset/"
label_file = "labels.json"
with open(os.path.join(label_dir, label_file), 'r') as f:
    labels = json.load(f)

# get the image file names and labels
image_name_list = [os.path.join(data_dir, str(image_name['id'])+'.nii') for image_name in labels]


label_list = [label['age'] for label in labels]
max_age = max(label_list)
min_age = min(label_list)
label_list = [[(label-min_age)/(max_age-min_age)] for label in label_list] # Not sure it is still a good idea to normalize the label for spearman loss

data_dicts = []
for image_name, label in zip(image_name_list, label_list):
    if os.path.exists(image_name):
        data_dicts.append({"image": image_name, "label": label})
train_files, val_files = data_dicts[:-200], data_dicts[-200:]

# %%
# define hyperparameters
batch_size = 20
num_workers = 10
train_sampler = None
lr = 1

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-500,
            a_max=1500, 
            b_min=0.0, 
            b_max=1.0, 
            clip=True,
        ),
        # RepeatChanneld(keys=["image"],repeats=3),
        ToTensord(keys=["image", "label"]),
        # RandCropByPosNegLabeld(
        #     keys=["image", "label"],
        #     label_key="label",
        #     spatial_size=(96, 96),
        #     pos=1,
        #     neg=1,
        #     num_samples=4,
        #     image_key="image",
        #     image_threshold=0,
        # ),
        # user can also add other random transforms
        # RandAffined(
        #     keys=['image', 'label'],
        #     mode=('bilinear', 'nearest'),
        #     prob=1.0, spatial_size=(96, 96),
        #     rotate_range=(0, 0, np.pi/15),
        #     scale_range=(0.1, 0.1, 0.1)),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image"]),
        EnsureChannelFirstd(keys=["image"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-500,
            a_max=1500,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        # # RepeatChanneld(keys=["image"],repeats=3),
        ToTensord(keys=["image", "label"]),
    ]
)

train_ds = Dataset(data=train_files, transform=train_transforms)
val_ds = Dataset(data=val_files, transform=val_transforms)

train_loader = DataLoader(train_ds, batch_size=batch_size, num_workers=num_workers, sampler=train_sampler,shuffle=True, drop_last=True)
val_loader = DataLoader(val_ds, batch_size=batch_size, num_workers=num_workers, shuffle=False, drop_last=True)

# %% [markdown]
# ## check the dataloader

# %%
from monai.utils import set_determinism, first
import matplotlib.pyplot as plt

check_ds = Dataset(data=train_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
iamge = check_data["image"][0][0]
label = check_data["label"][0]


# plot the slice [:, :, 50]
plt.figure("check", (12, 6))
plt.subplot(1, 2, 1)
plt.title("moving_image")
plt.imshow(iamge[:, :], cmap="gray")



plt.show()
plt.show()

# %%
check_data["label"].shape
# Out:
# torch.Size([1, 1])

# %% [markdown]
# ## Spearman loss

# %%
# class WeightedSpearmanLoss(nn.Module):
#     """
#         Spearman Loss
#     """

#     def __init__(self, *args, **kwargs) -> None:
#         super().__init__(*args, **kwargs)
    
#     def forward(self, pred: torch.tensor, target: torch.tensor, target_sort: torch.tensor, k=2, s=5, **kw) -> torch.tensor:
        
#         pred_rank = torchsort.soft_rank(pred, **kw)
#         target_rank = torchsort.soft_rank(target, **kw)
        
#         target_sort = target_sort.flatten()
#         W = torch.sqrt( (target_sort[pred_rank.flatten().long()-1] - target_sort[target_rank.flatten().long()-1]) ** 2 ).requires_grad_(False)
#         # w = torch.tensor([0,0,0,0,19])
#         pred_rank = pred_rank - pred_rank.mean()
#         pred_rank = pred_rank / pred_rank.norm()
#         target_rank = target_rank - target_rank.mean()
#         target_rank = target_rank / target_rank.norm()
        
#         W = 1/(1 + torch.exp(-k*(W-s)))
#         W = W / W.sum()*len(W)
#         return -(pred_rank * target_rank * W).sum()
    
class SpearmanLoss(nn.Module):
    """
        Spearman Loss
    """

    def __init__(self, *args, **kwargs) -> None:
        super().__init__(*args, **kwargs)
    
    def forward(self, pred: torch.tensor, target: torch.tensor, **kw) -> torch.tensor:
        """
            pred: (B, 1)
            target: (B, 1)
        """
        pred = torchsort.soft_rank(pred, **kw)
        target = torchsort.soft_rank(target, **kw)
        pred = pred - pred.mean()
        pred = pred / pred.norm()
        target = target - target.mean()
        target = target / target.norm()
        return -(pred * target).sum()

class Bachnorm(nn.Module):
    '''
        Batchnorm layer
    '''

    def __init__(self) -> None:
        super(Bachnorm, self).__init__()

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        '''
            x: (B, 1)
        '''
        mean = x.mean(dim=(0), keepdim=True)
        std = x.std(dim=(0), keepdim=True)
        return (x - mean) / (std + 1e-5)

# %%
def load_state_dict(model: nn.Module, pth_file: str):
    """
    This function is used to load pretrained models.
    """

    pattern_conv = re.compile(r"^(layer[1-4]\.\d\.(?:conv)\d\.)(\w*)$")
    pattern_bn = re.compile(r"^(layer[1-4]\.\d\.)(?:bn)(\d\.)(\w*)$")
    pattern_se = re.compile(r"^(layer[1-4]\.\d\.)(?:se_module.fc1.)(\w*)$")
    pattern_se2 = re.compile(r"^(layer[1-4]\.\d\.)(?:se_module.fc2.)(\w*)$")
    pattern_down_conv = re.compile(r"^(layer[1-4]\.\d\.)(?:downsample.0.)(\w*)$")
    pattern_down_bn = re.compile(r"^(layer[1-4]\.\d\.)(?:downsample.1.)(\w*)$")
    state_dict = torch.load(pth_file)
    for key in list(state_dict.keys()):
        new_key = None
        if pattern_conv.match(key):
            new_key = re.sub(pattern_conv, r"\1conv.\2", key)
        elif pattern_bn.match(key):
            new_key = re.sub(pattern_bn, r"\1conv\2adn.N.\3", key)
        elif pattern_se.match(key):
            state_dict[key] = state_dict[key].squeeze()
            new_key = re.sub(pattern_se, r"\1se_layer.fc.0.\2", key)
        elif pattern_se2.match(key):
            state_dict[key] = state_dict[key].squeeze()
            new_key = re.sub(pattern_se2, r"\1se_layer.fc.2.\2", key)
        elif pattern_down_conv.match(key):
            new_key = re.sub(pattern_down_conv, r"\1project.conv.\2", key)
        elif pattern_down_bn.match(key):
            new_key = re.sub(pattern_down_bn, r"\1project.adn.N.\2", key)
        if new_key:
            state_dict[new_key] = state_dict[key]
            del state_dict[key]

    model_dict = model.state_dict()
    state_dict = {
        k: v for k, v in state_dict.items() if (k in model_dict) and (model_dict[k].shape == state_dict[k].shape)
    }
    model_dict.update(state_dict)
    model.load_state_dict(model_dict)

# %%
device = torch.device("cuda:0")
model = SEResNet50(spatial_dims=2, in_channels=1, pretrained=False, num_classes=1)
seresnet50_file = '/isilon/datalake/cialab/scratch/cialab/Hao/work_record/Project2_CT_image/codes/CT_age/RadImageNet_pytorch/se_resnet50-ce0d4300.pth'
load_state_dict(model, seresnet50_file)

outputs = {}

def forward_hook(module, input, output):
    outputs["SEResNet50_output"] = output

# Registering forward hook for the last layer of SEResNet50 (before Sequential)
model.register_forward_hook(forward_hook)

# For gradients
gradients = {}

def backward_hook(module, grad_input, grad_output):
    gradients["SEResNet50_output"] = grad_output[0]  # grad_output is a tuple

# Registering backward hook for the last layer of SEResNet50
model.register_backward_hook(backward_hook)

model = nn.Sequential(model, Bachnorm())

model.to(device)
huber_loss = nn.SmoothL1Loss()
spearman_loss = SpearmanLoss()
# weighted_spearman_loss = WeightedSpearmanLoss()
optimizer = torch.optim.Adam(model.parameters(), lr)

# Number of epochs
loop_epochs = 50
num_loop = 2

# Cosine learning rate scheduler
scheduler = CosineAnnealingLR(optimizer, T_max=loop_epochs, eta_min=1e-7)

# Save the initial state of the model
initial_state = deepcopy(model.state_dict())

# %%
def spearman_hard(traget1, pred):
    pred = get_rank(pred, [i for i in range(pred.shape[1])]).float()
    traget1 = get_rank(traget1, [i for i in range(traget1.shape[1])]).float()
    pred = pred - pred.mean()
    pred = pred / pred.norm()
    traget1 = traget1 - traget1.mean()
    traget1 = traget1 / traget1.norm()
    return (pred * traget1).sum()

def weighted_spearmanr(pred, target, target_sort, k=2, s=5, **kw):
    pred_rank = torchsort.soft_rank(pred, **kw)
    target_rank = torchsort.soft_rank(target, **kw)
    
    target_sort = target_sort.flatten()
    W = torch.sqrt( (target_sort[pred_rank.flatten().long()-1] - target_sort[target_rank.flatten().long()-1]) ** 2 ).requires_grad_(False)
    # w = torch.tensor([0,0,0,0,19])
    pred_rank = pred_rank - pred_rank.mean()
    pred_rank = pred_rank / pred_rank.norm()
    target_rank = target_rank - target_rank.mean()
    target_rank = target_rank / target_rank.norm()
    
    W = 1/(1 + torch.exp(-k*(W-s)))

    return (pred_rank * target_rank * W).sum(), W

def spearmanr(pred, target, **kw):
    pred = torchsort.soft_rank(pred, **kw)
    target = torchsort.soft_rank(target, **kw)
    pred = pred - pred.mean()
    pred = pred / pred.norm()
    target = target - target.mean()
    target = target / target.norm()
    return (pred * target).sum()

def get_rank(x, indices):
   vals = x[list(range(len(x))), indices]
   return (x < vals[:, None]).long().sum(1)

def spearman_hard_eval(traget1, pred):
    pred = get_rank_eval(pred).float()
    traget1 = get_rank_eval(traget1).float()
    pred = pred - pred.mean()
    pred = pred / pred.norm()
    traget1 = traget1 - traget1.mean()
    traget1 = traget1 / traget1.norm()
    return (pred * traget1).sum()

def get_rank_eval(x):
   vals = x[0, :]
   return (x < vals[:, None]).long().sum(1)

# %%
x = torch.tensor([[1,2,3,4,5,5,4,3,2,1]])
get_rank_eval(x)
# Out:
# tensor([0, 2, 4, 6, 8, 8, 6, 4, 2, 0])

# %%
val_interval = 5

for lr in [0.5, 1, 1.5, 2, 5]:
    # Reset the model
    model.load_state_dict(deepcopy(initial_state))
    metric_val = []
    loss_val = []
    best_metric = -10
    for epoch in range(loop_epochs * num_loop):
        print("-" * 10)
        print(f"epoch {epoch + 1}/{loop_epochs * num_loop}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            step += 1
            inputs, labels = (
                batch_data["image"].to(device),
                batch_data["label"].to(device),
            )
            optimizer.zero_grad()
            output = model(inputs)
            # print(output)
            loss = spearman_loss(output.t(), labels.t())
            loss.backward()
            # print('output before sigmoid', outputs["SEResNet50_output"])
            # print('gradient of the las layer of SEResNet50', gradients["SEResNet50_output"])
            # break #####################################################################################################################

            optimizer.step()
            epoch_loss += loss.item()
            # if step ==2:#########################################################################################################
            #     break
            # # print(f"{step}/{len(train_ds) // train_loader.batch_size}, train_loss: {loss.item():.4f}")
        epoch_loss /= step
        # Step the scheduler
        scheduler.step()
        print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")
        
        # break #####################################################################################################################
    
        if (epoch+1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                val_spearman_metric = 0
                val_step = 0
                for val_data in val_loader:
                    val_images, val_labels = (
                        val_data["image"].to(device),
                        val_data["label"].to(device),
                    )
                    val_outputs = model(val_images)
                    val_loss = spearman_hard_eval(val_outputs.t(), val_labels.t())
                    val_spearman_metric += val_loss
                    val_step += 1
                val_spearman_metric /= val_step
                if val_spearman_metric > best_metric:
                    best_metric = val_spearman_metric
                    torch.save(model.state_dict(), "segmoid_best_metric_model_lr_{}_batchsize_{}.pth".format(lr, batch_size))
                print(f"current epoch: {epoch + 1} current spearman: {val_spearman_metric:.4f} best spearman: {best_metric:.4f}")
                metric_val.append(val_spearman_metric.cpu())
                loss_val.append(epoch_loss)
    # break #########################################################################################################################
    # Plot the loss curve
    plt.figure("train", (12, 6))
    plt.subplot(1, 2, 1)
    plt.title("Epoch Average Loss")
    x = [i*val_interval for i in range(len(loss_val))]
    plt.xlabel("epoch")
    plt.plot(x, loss_val, color="red")
    plt.subplot(1, 2, 2)
    plt.title("Epoch Average Spearman")
    x = [i*val_interval for i in range(len(metric_val))]
    plt.xlabel("epoch")
    plt.plot(x, metric_val, color="red")
    plt.savefig("segmoid_loss_lr_{}_batchsize_{}.png".format(lr, batch_size))
    plt.close("train")

    # save the loss and metric
    with open("segmoid_loss_lr_{}_batchsize_{}.txt".format(lr, batch_size), "w") as f:
        for i in loss_val:
            f.write(str(i))
            f.write("\n")
    with open("segmoid_metric_lr_{}_batchsize_{}.txt".format(lr, batch_size), "w") as f:
        for i in metric_val:
            f.write(str(i))
            f.write("\n")
# Out:
# ----------
# epoch 1/100
# /isilon/datalake/cialab/scratch/cialab/Hao/miniconda3/envs/rank/lib/python3.11/site-packages/torch/nn/modules/module.py:1344: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# epoch 1 average loss: -0.1093
# ----------
# epoch 2/100
# epoch 2 average loss: -0.1338
# ----------
# epoch 3/100
# epoch 3 average loss: -0.1541
# ----------
# epoch 4/100
# epoch 4 average loss: -0.2220
# ----------
# epoch 5/100
# epoch 5 average loss: -0.3697
# current epoch: 5 current spearman: 0.0442 best spearman: 0.0442
# ----------
# epoch 6/100
# epoch 6 average loss: -0.4292
# ----------
# epoch 7/100
# epoch 7 average loss: -0.4207
# ----------
# epoch 8/100
# epoch 8 average loss: -0.4165
# ----------
# epoch 9/100
# epoch 9 average loss: -0.4610
# ----------
# epoch 10/100
# epoch 10 average loss: -0.4830
# current epoch: 10 current spearman: 0.2729 best spearman: 0.2729
# ----------
# epoch 11/100
# epoch 11 average loss: -0.5359
# ----------
# epoch 12/100
# epoch 12 average loss: -0.4341
# ----------
# epoch 13/100
# epoch 13 average loss: -0.4755
# ----------
# epoch 14/100
# epoch 14 average loss: -0.5486
# ----------
# epoch 15/100
# epoch 15 average loss: -0.5651
# current epoch: 15 current spearman: 0.0821 best spearman: 0.2729
# ----------
# epoch 16/100
# epoch 16 average loss: -0.5802
# ----------
# epoch 17/100
# epoch 17 average loss: -0.5768
# ----------
# epoch 18/100
# epoch 18 average loss: -0.5978
# ----------
# epoch 19/100
# epoch 19 average loss: -0.6210
# ----------
# epoch 20/100
# epoch 20 average loss: -0.6751
# current epoch: 20 current spearman: 0.3128 best spearman: 0.3128
# ----------
# epoch 21/100
# epoch 21 average loss: -0.6829
# ----------
# epoch 22/100
# epoch 22 average loss: -0.7171
# ----------
# epoch 23/100
# epoch 23 average loss: -0.7113
# ----------
# epoch 24/100
# epoch 24 average loss: -0.7408
# ----------
# epoch 25/100
# epoch 25 average loss: -0.7999
# current epoch: 25 current spearman: 0.2119 best spearman: 0.3128
# ----------
# epoch 26/100
# epoch 26 average loss: -0.8115
# ----------
# epoch 27/100
# epoch 27 average loss: -0.8339
# ----------
# epoch 28/100
# epoch 28 average loss: -0.8612
# ----------
# epoch 29/100
# epoch 29 average loss: -0.6930
# ----------
# epoch 30/100
# epoch 30 average loss: -0.7440
# current epoch: 30 current spearman: 0.3375 best spearman: 0.3375
# ----------
# epoch 31/100
# epoch 31 average loss: -0.8399
# ----------
# epoch 32/100
# epoch 32 average loss: -0.8417
# ----------
# epoch 33/100
# epoch 33 average loss: -0.9026
# ----------
# epoch 34/100
# epoch 34 average loss: -0.9393
# ----------
# epoch 35/100
# epoch 35 average loss: -0.9600
# current epoch: 35 current spearman: 0.3066 best spearman: 0.3375
# ----------
# epoch 36/100
# epoch 36 average loss: -0.9700
# ----------
# epoch 37/100
# epoch 37 average loss: -0.9767
# ----------
# epoch 38/100
# epoch 38 average loss: -0.9803
# ----------
# epoch 39/100
# epoch 39 average loss: -0.9833
# ----------
# epoch 40/100
# epoch 40 average loss: -0.9863
# current epoch: 40 current spearman: 0.3221 best spearman: 0.3375
# ----------
# epoch 41/100
# epoch 41 average loss: -0.9897
# ----------
# epoch 42/100
# epoch 42 average loss: -0.9902
# ----------
# epoch 43/100
# epoch 43 average loss: -0.9910
# ----------
# epoch 44/100
# epoch 44 average loss: -0.9646
# ----------
# epoch 45/100
# epoch 45 average loss: -0.9751
# current epoch: 45 current spearman: 0.3010 best spearman: 0.3375
# ----------
# epoch 46/100
# epoch 46 average loss: -0.9860
# ----------
# epoch 47/100
# epoch 47 average loss: -0.9885
# ----------
# epoch 48/100
# epoch 48 average loss: -0.9898
# ----------
# epoch 49/100
# epoch 49 average loss: -0.9893
# ----------
# epoch 50/100
# epoch 50 average loss: -0.9903
# current epoch: 50 current spearman: 0.3039 best spearman: 0.3375
# ----------
# epoch 51/100
# epoch 51 average loss: -0.9897
# ----------
# epoch 52/100
# epoch 52 average loss: -0.9895
# ----------
# epoch 53/100
# epoch 53 average loss: -0.9919
# ----------
# epoch 54/100
# epoch 54 average loss: -0.9901
# ----------
# epoch 55/100
# epoch 55 average loss: -0.9908
# current epoch: 55 current spearman: 0.3036 best spearman: 0.3375
# ----------
# epoch 56/100
# epoch 56 average loss: -0.9911
# ----------
# epoch 57/100
# epoch 57 average loss: -0.9908
# ----------
# epoch 58/100
# epoch 58 average loss: -0.9930
# ----------
# epoch 59/100
# epoch 59 average loss: -0.9931
# ----------
# epoch 60/100
# epoch 60 average loss: -0.9928
# current epoch: 60 current spearman: 0.3351 best spearman: 0.3375
# ----------
# epoch 61/100
# epoch 61 average loss: -0.9919
# ----------
# epoch 62/100
# epoch 62 average loss: -0.9907
# ----------
# epoch 63/100
# epoch 63 average loss: -0.9862
# ----------
# epoch 64/100
# epoch 64 average loss: -0.9869
# ----------
# epoch 65/100
# epoch 65 average loss: -0.9851
# current epoch: 65 current spearman: 0.2989 best spearman: 0.3375
# ----------
# epoch 66/100
# epoch 66 average loss: -0.9782
# ----------
# epoch 67/100
# epoch 67 average loss: -0.9674
# ----------
# epoch 68/100
# epoch 68 average loss: -0.9626
# ----------
# epoch 69/100
# epoch 69 average loss: -0.9595
# ----------
# epoch 70/100
# epoch 70 average loss: -0.9559
# current epoch: 70 current spearman: 0.3718 best spearman: 0.3718
# ----------
# epoch 71/100
# epoch 71 average loss: -0.9249
# ----------
# epoch 72/100
# epoch 72 average loss: -0.8887
# ----------
# epoch 73/100
# epoch 73 average loss: -0.8666
# ----------
# epoch 74/100
# epoch 74 average loss: -0.8329
# ----------
# epoch 75/100
# epoch 75 average loss: -0.8604
# current epoch: 75 current spearman: 0.2955 best spearman: 0.3718
# ----------
# epoch 76/100
# epoch 76 average loss: -0.8556
# ----------
# epoch 77/100
# epoch 77 average loss: -0.8657
# ----------
# epoch 78/100
# epoch 78 average loss: -0.8568
# ----------
# epoch 79/100
# epoch 79 average loss: -0.8411
# ----------
# epoch 80/100
# epoch 80 average loss: -0.8789
# current epoch: 80 current spearman: 0.3190 best spearman: 0.3718
# ----------
# epoch 81/100
# epoch 81 average loss: -0.8676
# ----------
# epoch 82/100
# epoch 82 average loss: -0.8762
# ----------
# epoch 83/100
# epoch 83 average loss: -0.8861
# ----------
# epoch 84/100
# epoch 84 average loss: -0.9205
# ----------
# epoch 85/100
# epoch 85 average loss: -0.9462
# current epoch: 85 current spearman: 0.3226 best spearman: 0.3718
# ----------
# epoch 86/100
# epoch 86 average loss: -0.9475
# ----------
# epoch 87/100
# epoch 87 average loss: -0.9546
# ----------
# epoch 88/100
# epoch 88 average loss: -0.9544
# ----------
# epoch 89/100
# epoch 89 average loss: -0.9632
# ----------
# epoch 90/100
# epoch 90 average loss: -0.9555
# current epoch: 90 current spearman: 0.3296 best spearman: 0.3718
# ----------
# epoch 91/100
# epoch 91 average loss: -0.9607
# ----------
# epoch 92/100
# epoch 92 average loss: -0.9597
# ----------
# epoch 93/100
# epoch 93 average loss: -0.9570
# ----------
# epoch 94/100
# epoch 94 average loss: -0.9615
# ----------
# epoch 95/100
# epoch 95 average loss: -0.9640
# current epoch: 95 current spearman: 0.3386 best spearman: 0.3718
# ----------
# epoch 96/100
# epoch 96 average loss: -0.9548
# ----------
# epoch 97/100
# epoch 97 average loss: -0.9528
# ----------
# epoch 98/100
# epoch 98 average loss: -0.9578
# ----------
# epoch 99/100
# epoch 99 average loss: -0.9601
# ----------
# epoch 100/100
# epoch 100 average loss: -0.9610
# current epoch: 100 current spearman: 0.3408 best spearman: 0.3718
# ----------
# epoch 1/100
# epoch 1 average loss: -0.1278
# ----------
# epoch 2/100
# epoch 2 average loss: -0.1622
# ----------
# epoch 3/100
# epoch 3 average loss: -0.1458
# ----------
# epoch 4/100
# epoch 4 average loss: -0.1510
# ----------
# epoch 5/100
# epoch 5 average loss: -0.1965
# current epoch: 5 current spearman: 0.0551 best spearman: 0.0551
# ----------
# epoch 6/100
# epoch 6 average loss: -0.1773
# ----------
# epoch 7/100
# epoch 7 average loss: -0.2083
# ----------
# epoch 8/100
# epoch 8 average loss: -0.2926
# ----------
# epoch 9/100
# epoch 9 average loss: -0.3007
# ----------
# epoch 10/100
# epoch 10 average loss: -0.3057
# current epoch: 10 current spearman: 0.2348 best spearman: 0.2348
# ----------
# epoch 11/100
# epoch 11 average loss: -0.3582
# ----------
# epoch 12/100
# epoch 12 average loss: -0.4243
# ----------
# epoch 13/100
# epoch 13 average loss: -0.4945
# ----------
# epoch 14/100
# epoch 14 average loss: -0.4419
# ----------
# epoch 15/100
# epoch 15 average loss: -0.4914
# current epoch: 15 current spearman: 0.2514 best spearman: 0.2514
# ----------
# epoch 16/100
# epoch 16 average loss: -0.5452
# ----------
# epoch 17/100
# epoch 17 average loss: -0.5660
# ----------
# epoch 18/100
# epoch 18 average loss: -0.6122
# ----------
# epoch 19/100
# epoch 19 average loss: -0.6599
# ----------
# epoch 20/100
# epoch 20 average loss: -0.6652
# current epoch: 20 current spearman: 0.3390 best spearman: 0.3390
# ----------
# epoch 21/100
# epoch 21 average loss: -0.7177
# ----------
# epoch 22/100
# epoch 22 average loss: -0.7404
# ----------
# epoch 23/100
# epoch 23 average loss: -0.2540
# ----------
# epoch 24/100
# epoch 24 average loss: -0.1570
# ----------
# epoch 25/100
# epoch 25 average loss: -0.1955
# current epoch: 25 current spearman: 0.0063 best spearman: 0.3390
# ----------
# epoch 26/100
# epoch 26 average loss: -0.2885
# ----------
# epoch 27/100
# epoch 27 average loss: -0.4033
# ----------
# epoch 28/100
# epoch 28 average loss: -0.3851
# ----------
# epoch 29/100
# epoch 29 average loss: -0.5002
# ----------
# epoch 30/100
# epoch 30 average loss: -0.5553
# current epoch: 30 current spearman: 0.2390 best spearman: 0.3390
# ----------
# epoch 31/100
# epoch 31 average loss: -0.5871
# ----------
# epoch 32/100
# epoch 32 average loss: -0.5828
# ----------
# epoch 33/100
# epoch 33 average loss: -0.6366
# ----------
# epoch 34/100
# epoch 34 average loss: -0.6677
# ----------
# epoch 35/100
# epoch 35 average loss: -0.6835
# current epoch: 35 current spearman: 0.1868 best spearman: 0.3390
# ----------
# epoch 36/100
# epoch 36 average loss: -0.7386
# ----------
# epoch 37/100
# epoch 37 average loss: -0.7434
# ----------
# epoch 38/100
# epoch 38 average loss: -0.7837
# ----------
# epoch 39/100
# epoch 39 average loss: -0.7947
# ----------
# epoch 40/100
# epoch 40 average loss: -0.8064
# current epoch: 40 current spearman: 0.2377 best spearman: 0.3390
# ----------
# epoch 41/100
# epoch 41 average loss: -0.8251
# ----------
# epoch 42/100
# epoch 42 average loss: -0.8444
# ----------
# epoch 43/100
# epoch 43 average loss: -0.8561
# ----------
# epoch 44/100
# epoch 44 average loss: -0.8712
# ----------
# epoch 45/100
# epoch 45 average loss: -0.8753
# current epoch: 45 current spearman: 0.3165 best spearman: 0.3390
# ----------
# epoch 46/100
# epoch 46 average loss: -0.8887
# ----------
# epoch 47/100
# epoch 47 average loss: -0.8872
# ----------
# epoch 48/100
# epoch 48 average loss: -0.8933
# ----------
# epoch 49/100
# epoch 49 average loss: -0.9025
# ----------
# epoch 50/100
# epoch 50 average loss: -0.8953
# current epoch: 50 current spearman: 0.3095 best spearman: 0.3390
# ----------
# epoch 51/100
# epoch 51 average loss: -0.9003
# ----------
# epoch 52/100
# epoch 52 average loss: -0.9037
# ----------
# epoch 53/100
# epoch 53 average loss: -0.8931
# ----------
# epoch 54/100
# epoch 54 average loss: -0.8958
# ----------
# epoch 55/100
# epoch 55 average loss: -0.8962
# current epoch: 55 current spearman: 0.3169 best spearman: 0.3390
# ----------
# epoch 56/100
# epoch 56 average loss: -0.8929
# ----------
# epoch 57/100
# epoch 57 average loss: -0.8680
# ----------
# epoch 58/100
# epoch 58 average loss: -0.8884
# ----------
# epoch 59/100
# epoch 59 average loss: -0.8879
# ----------
# epoch 60/100
# epoch 60 average loss: -0.8030
# current epoch: 60 current spearman: 0.2087 best spearman: 0.3390
# ----------
# epoch 61/100
# epoch 61 average loss: -0.8324
# ----------
# epoch 62/100
# epoch 62 average loss: -0.8654
# ----------
# epoch 63/100
# epoch 63 average loss: -0.8544
# ----------
# epoch 64/100
# epoch 64 average loss: -0.8500
# ----------
# epoch 65/100
# epoch 65 average loss: -0.8379
# current epoch: 65 current spearman: 0.3159 best spearman: 0.3390
# ----------
# epoch 66/100
# epoch 66 average loss: -0.8309
# ----------
# epoch 67/100
# epoch 67 average loss: -0.8737
# ----------
# epoch 68/100
# epoch 68 average loss: -0.8413
# ----------
# epoch 69/100
# epoch 69 average loss: -0.8538
# ----------
# epoch 70/100
# epoch 70 average loss: -0.8044
# current epoch: 70 current spearman: 0.2633 best spearman: 0.3390
# ----------
# epoch 71/100
# epoch 71 average loss: -0.8231
# ----------
# epoch 72/100
# epoch 72 average loss: -0.7991
# ----------
# epoch 73/100
# epoch 73 average loss: -0.8037
# ----------
# epoch 74/100
# epoch 74 average loss: -0.8193
# ----------
# epoch 75/100
# epoch 75 average loss: -0.2382
# current epoch: 75 current spearman: 0.0286 best spearman: 0.3390
# ----------
# epoch 76/100
# epoch 76 average loss: -0.1909
# ----------
# epoch 77/100
# epoch 77 average loss: -0.1643
# ----------
# epoch 78/100
# epoch 78 average loss: -0.1473
# ----------
# epoch 79/100
# epoch 79 average loss: -0.2116
# ----------
# epoch 80/100
# epoch 80 average loss: -0.2444
# current epoch: 80 current spearman: 0.0931 best spearman: 0.3390
# ----------
# epoch 81/100
# epoch 81 average loss: -0.3221
# ----------
# epoch 82/100
# epoch 82 average loss: -0.3369
# ----------
# epoch 83/100
# epoch 83 average loss: -0.4395
# ----------
# epoch 84/100
# epoch 84 average loss: -0.4010
# ----------
# epoch 85/100
# epoch 85 average loss: -0.4298
# current epoch: 85 current spearman: -0.0229 best spearman: 0.3390
# ----------
# epoch 86/100
# epoch 86 average loss: -0.4997
# ----------
# epoch 87/100
# epoch 87 average loss: -0.5493
# ----------
# epoch 88/100
# epoch 88 average loss: -0.5507
# ----------
# epoch 89/100
# epoch 89 average loss: -0.5726
# ----------
# epoch 90/100
# epoch 90 average loss: -0.5288
# current epoch: 90 current spearman: 0.1892 best spearman: 0.3390
# ----------
# epoch 91/100
# epoch 91 average loss: -0.5495
# ----------
# epoch 92/100
# epoch 92 average loss: -0.5606
# ----------
# epoch 93/100
# epoch 93 average loss: -0.6064
# ----------
# epoch 94/100
# epoch 94 average loss: -0.6479
# ----------
# epoch 95/100
# epoch 95 average loss: -0.6614
# current epoch: 95 current spearman: 0.1123 best spearman: 0.3390
# ----------
# epoch 96/100
# epoch 96 average loss: -0.6457
# ----------
# epoch 97/100
# epoch 97 average loss: -0.6671
# ----------
# epoch 98/100
# epoch 98 average loss: -0.6972
# ----------
# epoch 99/100
# epoch 99 average loss: -0.6815
# ----------
# epoch 100/100
# epoch 100 average loss: -0.6749
# current epoch: 100 current spearman: 0.2809 best spearman: 0.3390
# ----------
# epoch 1/100
# epoch 1 average loss: 0.1350
# ----------
# epoch 2/100
# epoch 2 average loss: 0.0887
# ----------
# epoch 3/100
# epoch 3 average loss: -0.0150
# ----------
# epoch 4/100
# epoch 4 average loss: -0.0087
# ----------
# epoch 5/100
# epoch 5 average loss: -0.0099
# current epoch: 5 current spearman: 0.1665 best spearman: 0.1665
# ----------
# epoch 6/100
# epoch 6 average loss: -0.0101
# ----------
# epoch 7/100
# epoch 7 average loss: -0.0616
# ----------
# epoch 8/100
# epoch 8 average loss: -0.0212
# ----------
# epoch 9/100
# epoch 9 average loss: 0.0189
# ----------
# epoch 10/100
# epoch 10 average loss: -0.0461
# current epoch: 10 current spearman: 0.0664 best spearman: 0.1665
# ----------
# epoch 11/100
# epoch 11 average loss: -0.0697
# ----------
# epoch 12/100
# epoch 12 average loss: -0.1509
# ----------
# epoch 13/100
# epoch 13 average loss: -0.2407
# ----------
# epoch 14/100
# epoch 14 average loss: -0.1731
# ----------
# epoch 15/100
# epoch 15 average loss: -0.1340
# current epoch: 15 current spearman: 0.0792 best spearman: 0.1665
# ----------
# epoch 16/100
# epoch 16 average loss: -0.1169
# ----------
# epoch 17/100
# epoch 17 average loss: -0.1246
# ----------
# epoch 18/100
# epoch 18 average loss: -0.1825
# ----------
# epoch 19/100
# epoch 19 average loss: -0.1893
# ----------
# epoch 20/100
# epoch 20 average loss: -0.2035
# current epoch: 20 current spearman: 0.2536 best spearman: 0.2536
# ----------
# epoch 21/100
# epoch 21 average loss: -0.2449
# ----------
# epoch 22/100
# epoch 22 average loss: -0.1412
# ----------
# epoch 23/100
# epoch 23 average loss: -0.2134
# ----------
# epoch 24/100
# epoch 24 average loss: -0.2993
# ----------
# epoch 25/100
# epoch 25 average loss: -0.3184
# current epoch: 25 current spearman: 0.2881 best spearman: 0.2881
# ----------
# epoch 26/100
# epoch 26 average loss: -0.3662
# ----------
# epoch 27/100
# epoch 27 average loss: -0.4695
# ----------
# epoch 28/100
# epoch 28 average loss: -0.5502
# ----------
# epoch 29/100
# epoch 29 average loss: -0.4756
# ----------
# epoch 30/100
# epoch 30 average loss: -0.3974
# current epoch: 30 current spearman: 0.1295 best spearman: 0.2881
# ----------
# epoch 31/100
# epoch 31 average loss: -0.4725
# ----------
# epoch 32/100
# epoch 32 average loss: -0.5299
# ----------
# epoch 33/100
# epoch 33 average loss: -0.5677
# ----------
# epoch 34/100
# epoch 34 average loss: -0.5943
# ----------
# epoch 35/100
# epoch 35 average loss: -0.5230
# current epoch: 35 current spearman: 0.2705 best spearman: 0.2881
# ----------
# epoch 36/100
# epoch 36 average loss: -0.6132
# ----------
# epoch 37/100
# epoch 37 average loss: -0.5754
# ----------
# epoch 38/100
# epoch 38 average loss: -0.0579
# ----------
# epoch 39/100
# epoch 39 average loss: -0.0629
# ----------
# epoch 40/100
# epoch 40 average loss: -0.0650
# current epoch: 40 current spearman: -0.0289 best spearman: 0.2881
# ----------
# epoch 41/100
# epoch 41 average loss: -0.0783
# ----------
# epoch 42/100
# epoch 42 average loss: -0.0700
# ----------
# epoch 43/100
# epoch 43 average loss: -0.0837
# ----------
# epoch 44/100
# epoch 44 average loss: -0.0614
# ----------
# epoch 45/100
# epoch 45 average loss: -0.0534
# current epoch: 45 current spearman: -0.0227 best spearman: 0.2881
# ----------
# epoch 46/100
# epoch 46 average loss: -0.0927
# ----------
# epoch 47/100
# epoch 47 average loss: -0.0829
# ----------
# epoch 48/100
# epoch 48 average loss: -0.0832
# ----------
# epoch 49/100
# epoch 49 average loss: -0.0584
# ----------
# epoch 50/100
# epoch 50 average loss: -0.0784
# current epoch: 50 current spearman: -0.0196 best spearman: 0.2881
# ----------
# epoch 51/100
# epoch 51 average loss: -0.0652
# ----------
# epoch 52/100
# epoch 52 average loss: -0.0625
# ----------
# epoch 53/100
# epoch 53 average loss: -0.0762
# ----------
# epoch 54/100
# epoch 54 average loss: -0.0906
# ----------
# epoch 55/100
# epoch 55 average loss: -0.0694
# current epoch: 55 current spearman: -0.0193 best spearman: 0.2881
# ----------
# epoch 56/100
# epoch 56 average loss: -0.0706
# ----------
# epoch 57/100
# epoch 57 average loss: -0.0797
# ----------
# epoch 58/100
# epoch 58 average loss: -0.0920
# ----------
# epoch 59/100
# epoch 59 average loss: -0.0641
# ----------
# epoch 60/100
# epoch 60 average loss: -0.0774
# current epoch: 60 current spearman: -0.0026 best spearman: 0.2881
# ----------
# epoch 61/100
# epoch 61 average loss: -0.0704
# ----------
# epoch 62/100
# epoch 62 average loss: -0.0916
# ----------
# epoch 63/100
# epoch 63 average loss: -0.0985
# ----------
# epoch 64/100
# epoch 64 average loss: -0.0873
# ----------
# epoch 65/100
# epoch 65 average loss: -0.0824
# current epoch: 65 current spearman: 0.0320 best spearman: 0.2881
# ----------
# epoch 66/100
# epoch 66 average loss: -0.1252
# ----------
# epoch 67/100
# epoch 67 average loss: -0.1054
# ----------
# epoch 68/100
# epoch 68 average loss: -0.1403
# ----------
# epoch 69/100
# epoch 69 average loss: -0.1591
# ----------
# epoch 70/100
# epoch 70 average loss: -0.1970
# current epoch: 70 current spearman: 0.1998 best spearman: 0.2881
# ----------
# epoch 71/100
# epoch 71 average loss: -0.2673
# ----------
# epoch 72/100
# epoch 72 average loss: -0.3110
# ----------
# epoch 73/100
# epoch 73 average loss: -0.3805
# ----------
# epoch 74/100
# epoch 74 average loss: -0.4016
# ----------
# epoch 75/100
# epoch 75 average loss: -0.4504
# current epoch: 75 current spearman: 0.3169 best spearman: 0.3169
# ----------
# epoch 76/100
# epoch 76 average loss: -0.5092
# ----------
# epoch 77/100
# epoch 77 average loss: -0.5613
# ----------
# epoch 78/100
# epoch 78 average loss: -0.5321
# ----------
# epoch 79/100
# epoch 79 average loss: -0.5779
# ----------
# epoch 80/100
# epoch 80 average loss: -0.5155
# current epoch: 80 current spearman: 0.1886 best spearman: 0.3169
# ----------
# epoch 81/100
# epoch 81 average loss: -0.5806
# ----------
# epoch 82/100
# epoch 82 average loss: -0.6095
# ----------
# epoch 83/100
# epoch 83 average loss: -0.6390
# ----------
# epoch 84/100
# epoch 84 average loss: -0.2955
# ----------
# epoch 85/100
# epoch 85 average loss: -0.3972
# current epoch: 85 current spearman: 0.1469 best spearman: 0.3169
# ----------
# epoch 86/100
# epoch 86 average loss: -0.4777
# ----------
# epoch 87/100
# epoch 87 average loss: -0.5131
# ----------
# epoch 88/100
# epoch 88 average loss: -0.5318
# ----------
# epoch 89/100
# epoch 89 average loss: -0.5740
# ----------
# epoch 90/100
# epoch 90 average loss: -0.6079
# current epoch: 90 current spearman: 0.3187 best spearman: 0.3187
# ----------
# epoch 91/100
# epoch 91 average loss: -0.6121
# ----------
# epoch 92/100
# epoch 92 average loss: -0.6150
# ----------
# epoch 93/100
# epoch 93 average loss: -0.6469
# ----------
# epoch 94/100
# epoch 94 average loss: -0.6535
# ----------
# epoch 95/100
# epoch 95 average loss: -0.6601
# current epoch: 95 current spearman: 0.3227 best spearman: 0.3227
# ----------
# epoch 96/100
# epoch 96 average loss: -0.7006
# ----------
# epoch 97/100
# epoch 97 average loss: -0.7026
# ----------
# epoch 98/100
# epoch 98 average loss: -0.7008
# ----------
# epoch 99/100
# epoch 99 average loss: -0.7185
# ----------
# epoch 100/100
# epoch 100 average loss: -0.7644
# current epoch: 100 current spearman: 0.3322 best spearman: 0.3322
# ----------
# epoch 1/100
# epoch 1 average loss: -0.1131
# ----------
# epoch 2/100
# epoch 2 average loss: -0.0511
# ----------
# epoch 3/100
# epoch 3 average loss: 0.0723
# ----------
# epoch 4/100
# epoch 4 average loss: -0.0475
# ----------
# epoch 5/100
# epoch 5 average loss: -0.1138
# current epoch: 5 current spearman: 0.0494 best spearman: 0.0494
# ----------
# epoch 6/100
# epoch 6 average loss: -0.1530
# ----------
# epoch 7/100
# epoch 7 average loss: -0.1315
# ----------
# epoch 8/100
# epoch 8 average loss: -0.1605
# ----------
# epoch 9/100
# epoch 9 average loss: -0.1188
# ----------
# epoch 10/100
# epoch 10 average loss: -0.1316
# current epoch: 10 current spearman: -0.0602 best spearman: 0.0494
# ----------
# epoch 11/100
# epoch 11 average loss: -0.1918
# ----------
# epoch 12/100
# epoch 12 average loss: -0.2767
# ----------
# epoch 13/100
# epoch 13 average loss: -0.3260
# ----------
# epoch 14/100
# epoch 14 average loss: -0.3528
# ----------
# epoch 15/100
# epoch 15 average loss: -0.4057
# current epoch: 15 current spearman: 0.0224 best spearman: 0.0494
# ----------
# epoch 16/100
# epoch 16 average loss: -0.3703
# ----------
# epoch 17/100
# epoch 17 average loss: -0.3965
# ----------
# epoch 18/100
# epoch 18 average loss: -0.4448
# ----------
# epoch 19/100
# epoch 19 average loss: -0.4058
# ----------
# epoch 20/100
# epoch 20 average loss: -0.4920
# current epoch: 20 current spearman: 0.3031 best spearman: 0.3031
# ----------
# epoch 21/100
# epoch 21 average loss: -0.5204
# ----------
# epoch 22/100
# epoch 22 average loss: -0.5707
# ----------
# epoch 23/100
# epoch 23 average loss: -0.5755
# ----------
# epoch 24/100
# epoch 24 average loss: -0.5582
# ----------
# epoch 25/100
# epoch 25 average loss: -0.5665
# current epoch: 25 current spearman: 0.3506 best spearman: 0.3506
# ----------
# epoch 26/100
# epoch 26 average loss: -0.6292
# ----------
# epoch 27/100
# epoch 27 average loss: -0.6467
# ----------
# epoch 28/100
# epoch 28 average loss: -0.6555
# ----------
# epoch 29/100
# epoch 29 average loss: -0.6772
# ----------
# epoch 30/100
# epoch 30 average loss: -0.6884
# current epoch: 30 current spearman: 0.3578 best spearman: 0.3578
# ----------
# epoch 31/100
# epoch 31 average loss: -0.6875
# ----------
# epoch 32/100
# epoch 32 average loss: -0.7141
# ----------
# epoch 33/100
# epoch 33 average loss: -0.7391
# ----------
# epoch 34/100
# epoch 34 average loss: -0.7499
# ----------
# epoch 35/100
# epoch 35 average loss: -0.6710
# current epoch: 35 current spearman: 0.2946 best spearman: 0.3578
# ----------
# epoch 36/100
# epoch 36 average loss: -0.7020
# ----------
# epoch 37/100
# epoch 37 average loss: -0.7182
# ----------
# epoch 38/100
# epoch 38 average loss: -0.7316
# ----------
# epoch 39/100
# epoch 39 average loss: -0.7858
# ----------
# epoch 40/100
# epoch 40 average loss: -0.8096
# current epoch: 40 current spearman: 0.2861 best spearman: 0.3578
# ----------
# epoch 41/100
# epoch 41 average loss: -0.8053
# ----------
# epoch 42/100
# epoch 42 average loss: -0.8314
# ----------
# epoch 43/100
# epoch 43 average loss: -0.8358
# ----------
# epoch 44/100
# epoch 44 average loss: -0.8377
# ----------
# epoch 45/100
# epoch 45 average loss: -0.8447
# current epoch: 45 current spearman: 0.3406 best spearman: 0.3578
# ----------
# epoch 46/100
# epoch 46 average loss: -0.8542
# ----------
# epoch 47/100
# epoch 47 average loss: -0.8667
# ----------
# epoch 48/100
# epoch 48 average loss: -0.8641
# ----------
# epoch 49/100
# epoch 49 average loss: -0.8586
# ----------
# epoch 50/100
# epoch 50 average loss: -0.8644
# current epoch: 50 current spearman: 0.3603 best spearman: 0.3603
# ----------
# epoch 51/100
# epoch 51 average loss: -0.8639
# ----------
# epoch 52/100
# epoch 52 average loss: -0.8789
# ----------
# epoch 53/100
# epoch 53 average loss: -0.8648
# ----------
# epoch 54/100
# epoch 54 average loss: -0.8604
# ----------
# epoch 55/100
# epoch 55 average loss: -0.8658
# current epoch: 55 current spearman: 0.3446 best spearman: 0.3603
# ----------
# epoch 56/100
# epoch 56 average loss: -0.8584
# ----------
# epoch 57/100
# epoch 57 average loss: -0.8705
# ----------
# epoch 58/100
# epoch 58 average loss: -0.8612
# ----------
# epoch 59/100
# epoch 59 average loss: -0.8767
# ----------
# epoch 60/100
# epoch 60 average loss: -0.8659
# current epoch: 60 current spearman: 0.4067 best spearman: 0.4067
# ----------
# epoch 61/100
# epoch 61 average loss: -0.8530
# ----------
# epoch 62/100
# epoch 62 average loss: -0.8523
# ----------
# epoch 63/100
# epoch 63 average loss: -0.8616
# ----------
# epoch 64/100
# epoch 64 average loss: -0.8562
# ----------
# epoch 65/100
# epoch 65 average loss: -0.8128
# current epoch: 65 current spearman: 0.3834 best spearman: 0.4067
# ----------
# epoch 66/100
# epoch 66 average loss: -0.8275
# ----------
# epoch 67/100
# epoch 67 average loss: -0.7999
# ----------
# epoch 68/100
# epoch 68 average loss: -0.8127
# ----------
# epoch 69/100
# epoch 69 average loss: -0.8375
# ----------
# epoch 70/100
# epoch 70 average loss: -0.8136
# current epoch: 70 current spearman: 0.1949 best spearman: 0.4067
# ----------
# epoch 71/100
# epoch 71 average loss: -0.8175
# ----------
# epoch 72/100
# epoch 72 average loss: -0.8289
# ----------
# epoch 73/100
# epoch 73 average loss: -0.7964
# ----------
# epoch 74/100
# epoch 74 average loss: -0.8177
# ----------
# epoch 75/100
# epoch 75 average loss: -0.8396
# current epoch: 75 current spearman: 0.2497 best spearman: 0.4067
# ----------
# epoch 76/100
# epoch 76 average loss: -0.8199
# ----------
# epoch 77/100
# epoch 77 average loss: -0.8599
# ----------
# epoch 78/100
# epoch 78 average loss: -0.8640
# ----------
# epoch 79/100
# epoch 79 average loss: -0.2098
# ----------
# epoch 80/100
# epoch 80 average loss: -0.1660
# current epoch: 80 current spearman: 0.2064 best spearman: 0.4067
# ----------
# epoch 81/100
# epoch 81 average loss: -0.2077
# ----------
# epoch 82/100
# epoch 82 average loss: -0.2846
# ----------
# epoch 83/100
# epoch 83 average loss: -0.2909
# ----------
# epoch 84/100
# epoch 84 average loss: -0.4122
# ----------
# epoch 85/100
# epoch 85 average loss: -0.3316
# current epoch: 85 current spearman: 0.2639 best spearman: 0.4067
# ----------
# epoch 86/100
# epoch 86 average loss: -0.3922
# ----------
# epoch 87/100
# epoch 87 average loss: -0.3986
# ----------
# epoch 88/100
# epoch 88 average loss: -0.4826
# ----------
# epoch 89/100
# epoch 89 average loss: -0.4470
# ----------
# epoch 90/100
# epoch 90 average loss: -0.4596
# current epoch: 90 current spearman: 0.2542 best spearman: 0.4067
# ----------
# epoch 91/100
# epoch 91 average loss: -0.5181
# ----------
# epoch 92/100
# epoch 92 average loss: -0.5535
# ----------
# epoch 93/100
# epoch 93 average loss: -0.5405
# ----------
# epoch 94/100
# epoch 94 average loss: -0.5900
# ----------
# epoch 95/100
# epoch 95 average loss: -0.5662
# current epoch: 95 current spearman: 0.3601 best spearman: 0.4067
# ----------
# epoch 96/100
# epoch 96 average loss: -0.5922
# ----------
# epoch 97/100
# epoch 97 average loss: -0.5832
# ----------
# epoch 98/100
# epoch 98 average loss: -0.6087
# ----------
# epoch 99/100
# epoch 99 average loss: -0.6101
# ----------
# epoch 100/100
# epoch 100 average loss: -0.7085
# current epoch: 100 current spearman: 0.3405 best spearman: 0.4067
# ----------
# epoch 1/100
# epoch 1 average loss: -0.1390
# ----------
# epoch 2/100
# epoch 2 average loss: -0.1682
# ----------
# epoch 3/100
# epoch 3 average loss: -0.1710
# ----------
# epoch 4/100
# epoch 4 average loss: -0.1966
# ----------
# epoch 5/100
# epoch 5 average loss: -0.2576
# current epoch: 5 current spearman: 0.0650 best spearman: 0.0650
# ----------
# epoch 6/100
# epoch 6 average loss: -0.3214
# ----------
# epoch 7/100
# epoch 7 average loss: -0.3746
# ----------
# epoch 8/100
# epoch 8 average loss: -0.4809
# ----------
# epoch 9/100
# epoch 9 average loss: -0.4236
# ----------
# epoch 10/100
# epoch 10 average loss: -0.5141
# current epoch: 10 current spearman: 0.1947 best spearman: 0.1947
# ----------
# epoch 11/100
# epoch 11 average loss: -0.5929
# ----------
# epoch 12/100
# epoch 12 average loss: -0.6289
# ----------
# epoch 13/100
# epoch 13 average loss: -0.1789
# ----------
# epoch 14/100
# epoch 14 average loss: -0.1694
# ----------
# epoch 15/100
# epoch 15 average loss: -0.2219
# current epoch: 15 current spearman: 0.0728 best spearman: 0.1947
# ----------
# epoch 16/100
# epoch 16 average loss: -0.3590
# ----------
# epoch 17/100
# epoch 17 average loss: -0.3937
# ----------
# epoch 18/100
# epoch 18 average loss: -0.3468
# ----------
# epoch 19/100
# epoch 19 average loss: -0.4273
# ----------
# epoch 20/100
# epoch 20 average loss: -0.5114
# current epoch: 20 current spearman: 0.1023 best spearman: 0.1947
# ----------
# epoch 21/100
# epoch 21 average loss: -0.5378
# ----------
# epoch 22/100
# epoch 22 average loss: -0.4431
# ----------
# epoch 23/100
# epoch 23 average loss: -0.5074
# ----------
# epoch 24/100
# epoch 24 average loss: -0.2581
# ----------
# epoch 25/100
# epoch 25 average loss: -0.1372
# current epoch: 25 current spearman: 0.0762 best spearman: 0.1947
# ----------
# epoch 26/100
# epoch 26 average loss: -0.2019
# ----------
# epoch 27/100
# epoch 27 average loss: -0.2523
# ----------
# epoch 28/100
# epoch 28 average loss: -0.1777
# ----------
# epoch 29/100
# epoch 29 average loss: -0.1951
# ----------
# epoch 30/100
# epoch 30 average loss: -0.2904
# current epoch: 30 current spearman: 0.1156 best spearman: 0.1947
# ----------
# epoch 31/100
# epoch 31 average loss: -0.3238
# ----------
# epoch 32/100
# epoch 32 average loss: -0.3359
# ----------
# epoch 33/100
# epoch 33 average loss: -0.4021
# ----------
# epoch 34/100
# epoch 34 average loss: -0.4242
# ----------
# epoch 35/100
# epoch 35 average loss: -0.4669
# current epoch: 35 current spearman: 0.1459 best spearman: 0.1947
# ----------
# epoch 36/100
# epoch 36 average loss: -0.4622
# ----------
# epoch 37/100
# epoch 37 average loss: -0.5094
# ----------
# epoch 38/100
# epoch 38 average loss: -0.5245
# ----------
# epoch 39/100
# epoch 39 average loss: -0.5610
# ----------
# epoch 40/100
# epoch 40 average loss: -0.5657
# current epoch: 40 current spearman: 0.2626 best spearman: 0.2626
# ----------
# epoch 41/100
# epoch 41 average loss: -0.5966
# ----------
# epoch 42/100
# epoch 42 average loss: -0.6251
# ----------
# epoch 43/100
# epoch 43 average loss: -0.6498
# ----------
# epoch 44/100
# epoch 44 average loss: -0.6157
# ----------
# epoch 45/100
# epoch 45 average loss: -0.6300
# current epoch: 45 current spearman: 0.2539 best spearman: 0.2626
# ----------
# epoch 46/100
# epoch 46 average loss: -0.6709
# ----------
# epoch 47/100
# epoch 47 average loss: -0.6670
# ----------
# epoch 48/100
# epoch 48 average loss: -0.6819
# ----------
# epoch 49/100
# epoch 49 average loss: -0.6816
# ----------
# epoch 50/100
# epoch 50 average loss: -0.6776
# current epoch: 50 current spearman: 0.2489 best spearman: 0.2626
# ----------
# epoch 51/100
# epoch 51 average loss: -0.6800
# ----------
# epoch 52/100
# epoch 52 average loss: -0.6771
# ----------
# epoch 53/100
# epoch 53 average loss: -0.6872
# ----------
# epoch 54/100
# epoch 54 average loss: -0.6594
# ----------
# epoch 55/100
# epoch 55 average loss: -0.6744
# current epoch: 55 current spearman: 0.2602 best spearman: 0.2626
# ----------
# epoch 56/100
# epoch 56 average loss: -0.6876
# ----------
# epoch 57/100
# epoch 57 average loss: -0.6657
# ----------
# epoch 58/100
# epoch 58 average loss: -0.6865
# ----------
# epoch 59/100
# epoch 59 average loss: -0.6777
# ----------
# epoch 60/100
# epoch 60 average loss: -0.6750
# current epoch: 60 current spearman: 0.2634 best spearman: 0.2634
# ----------
# epoch 61/100
# epoch 61 average loss: -0.6897
# ----------
# epoch 62/100
# epoch 62 average loss: -0.6818
# ----------
# epoch 63/100
# epoch 63 average loss: -0.6530
# ----------
# epoch 64/100
# epoch 64 average loss: -0.7072
# ----------
# epoch 65/100
# epoch 65 average loss: -0.6167
# current epoch: 65 current spearman: 0.0127 best spearman: 0.2634
# ----------
# epoch 66/100
# epoch 66 average loss: -0.6602
# ----------
# epoch 67/100
# epoch 67 average loss: -0.6851
# ----------
# epoch 68/100
# epoch 68 average loss: -0.6926
# ----------
# epoch 69/100
# epoch 69 average loss: -0.5830
# ----------
# epoch 70/100
# epoch 70 average loss: -0.2117
# current epoch: 70 current spearman: -0.0475 best spearman: 0.2634
# ----------
# epoch 71/100
# epoch 71 average loss: -0.2968
# ----------
# epoch 72/100
# epoch 72 average loss: -0.3380
# ----------
# epoch 73/100
# epoch 73 average loss: -0.3478
# ----------
# epoch 74/100
# epoch 74 average loss: -0.4044
# ----------
# epoch 75/100
# epoch 75 average loss: -0.4180
# current epoch: 75 current spearman: -0.0124 best spearman: 0.2634
# ----------
# epoch 76/100
# epoch 76 average loss: -0.4111
# ----------
# epoch 77/100
# epoch 77 average loss: -0.4728
# ----------
# epoch 78/100
# epoch 78 average loss: -0.4217
# ----------
# epoch 79/100
# epoch 79 average loss: -0.5041
# ----------
# epoch 80/100
# epoch 80 average loss: -0.5197
# current epoch: 80 current spearman: 0.1218 best spearman: 0.2634
# ----------
# epoch 81/100
# epoch 81 average loss: -0.4794
# ----------
# epoch 82/100
# epoch 82 average loss: -0.5523
# ----------
# epoch 83/100
# epoch 83 average loss: -0.5896
# ----------
# epoch 84/100
# epoch 84 average loss: -0.5961
# ----------
# epoch 85/100
# epoch 85 average loss: -0.6161
# current epoch: 85 current spearman: 0.1249 best spearman: 0.2634
# ----------
# epoch 86/100
# epoch 86 average loss: -0.6158
# ----------
# epoch 87/100
# epoch 87 average loss: -0.6247
# ----------
# epoch 88/100
# epoch 88 average loss: -0.6755
# ----------
# epoch 89/100
# epoch 89 average loss: -0.6871
# ----------
# epoch 90/100
# epoch 90 average loss: -0.7339
# current epoch: 90 current spearman: 0.2323 best spearman: 0.2634
# ----------
# epoch 91/100
# epoch 91 average loss: -0.7228
# ----------
# epoch 92/100
# epoch 92 average loss: -0.7701
# ----------
# epoch 93/100
# epoch 93 average loss: -0.7741
# ----------
# epoch 94/100
# epoch 94 average loss: -0.7964
# ----------
# epoch 95/100
# epoch 95 average loss: -0.7459
# current epoch: 95 current spearman: 0.1594 best spearman: 0.2634
# ----------
# epoch 96/100
# epoch 96 average loss: -0.7866
# ----------
# epoch 97/100
# epoch 97 average loss: -0.7960
# ----------
# epoch 98/100
# epoch 98 average loss: -0.8168
# ----------
# epoch 99/100
# epoch 99 average loss: -0.8024
# ----------
# epoch 100/100
# epoch 100 average loss: -0.8588
# current epoch: 100 current spearman: 0.3229 best spearman: 0.3229

# %%
model[0](inputs)
# Out:
# metatensor([[ 17769.7871],
#         [ 21265.3047],
#         [ 13598.2188],
#         [ 97460.5781],
#         [ 56205.8906],
#         [121754.3984],
#         [ 42944.2109],
#         [ 63570.8242],
#         [ -6203.3242],
#         [ 35129.2344],
#         [ 54120.4961],
#         [ 87232.0000],
#         [ 85317.6641],
#         [ 82768.5234],
#         [ 98850.8438],
#         [  5066.6665],
#         [ 46426.6133],
#         [ 11458.9688],
#         [ 87066.7812],
#         [ 29964.7871]], device='cuda:0', grad_fn=<AliasBackward0>)

# %%
# Plot the loss curve
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i*val_interval for i in range(len(loss_val))]
plt.xlabel("epoch")
plt.plot(x, loss_val, color="red")
plt.subplot(1, 2, 2)
plt.title("Epoch Average Spearman")
x = [i*val_interval for i in range(len(metric_val))]
plt.xlabel("epoch")
plt.plot(x, [i.cpu() for i in metric_val], color="red")
plt.savefig("loss_lr_{}_batchsize_{}.png".format(lr, batch_size))

# %%
# exit()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
